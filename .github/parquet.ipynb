# %%
import pandas as pd
df = pd.read_parquet("data/bronze/dispatch_scada.parquet")
print(df.head())
# Out:
#        SETTLEMENTDATE      DUID  SCADAVALUE
# 0 2026-02-22 06:45:00    ADPBA1     0.04100
# 1 2026-02-22 06:45:00    ADPPV1     0.00000
# 2 2026-02-22 06:45:00    AGLHAL    28.87815
# 3 2026-02-22 06:45:00    AGLSOM     0.00000
# 4 2026-02-22 06:45:00  ALDGASF1   102.21159
